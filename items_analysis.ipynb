# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
# %matplotlib inline
df_item = pd.read_csv('data_code/item.csv')
df_item
# Out:
#       Item_id            Item_Description         Category  Pack  \
# 0         101     Kanna's Grapefruit Soda  Grapefruit Soda     6
# 1         102      Alphonse's Fruit Punch      Fruit Punch     6
# 2         103    Yummy Surstromming Juice              NaN     1
# 3         107   Tamaki's Watermelon Cream       Cream Soda     6
# 4         108     Kaori's Grapefruit Soda  Grapefruit Soda     6
# ...       ...                         ...              ...   ...
# 4161   994644        Saitama's Cream Soda       Cream Soda     6
# 4162   994786  Kenji's Vanilla Cream Soda       Cream Soda     6
# 4163   994972  Tanya's Vanilla Cream Soda       Cream Soda     6
# 4164   995606         Sakura's Cream Soda       Cream Soda    12
# 4165   996026        Tetsuya's Cream Soda       Cream Soda     6
#
#       Bottle_Volume_ml  Bottle_Cost  Bottle_Retail_Price
# 0                750.0         4.32                 6.48
# 1                800.0         3.33                 5.00
# ...

# %%
df_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4166 entries, 0 to 4165
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Item_id              4166 non-null   object
#  1   Item_Description     4166 non-null   object
#  2   Category             4162 non-null   object
#  3   Pack                 4166 non-null   int64
#  4   Bottle_Volume_ml     4166 non-null   float64
#  5   Bottle_Cost          4166 non-null   float64
#  6   Bottle_Retail_Price  4163 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 228.0+ KB

# %%
df_item.describe()
# Out:
#              Item_id         Pack  Bottle_Volume_ml  Bottle_Cost  \
# count    4166.000000  4166.000000       4166.000000  4166.000000
# mean   154512.392943    11.260442        936.963274     3.648721
# std    292382.354448    11.913901       6244.415564     9.348512
# min       101.000000     1.000000          0.000000     1.500000
# 25%     28799.250000     6.000000        750.000000     2.360000
# 50%     43336.500000    12.000000        750.000000     2.860000
# 75%     78591.500000    12.000000        750.000000     3.610000
# max    996026.000000   336.000000     378000.000000   500.000000
#
#        Bottle_Retail_Price
# count          4163.000000
# mean              5.485763
# std              14.027764
# min               2.450000
# 25%               3.580000
# 50%               4.300000
# 75%               5.420000
# max             750.000000

# %%
df_item['Item_id'].apply(str)
df_item['Item_id'] = df_item['Item_id'].apply(str)

# %%
df_item.Item_id
# Out:
# 0          101
# 1          102
# 2          103
# 3          107
# 4          108
#          ...
# 4161    994644
# 4162    994786
# 4163    994972
# 4164    995606
# 4165    996026
# Name: Item_id, Length: 4166, dtype: object

# %% [markdown]
# # Scatterplots: Volume vs. Cost

# %%
f,ax=plt.subplots(figsize=(17,10))
plt.scatter(df_item['Bottle_Volume_ml']/1000, df_item['Bottle_Cost'], alpha = 0.5)
ax.set_title('Volume vs. Cost-No limits')
plt.xlabel('Volume (liter)')
plt.ylabel('Cost')
plt.show()

# %%
f,ax=plt.subplots(figsize=(17,10))
plt.scatter(df_item['Bottle_Volume_ml']/1000, df_item['Bottle_Cost'], alpha = 0.35)
# sns.swarmplot(df_item['Bottle_Volume_ml'], df_item['Bottle_Cost'])
ax.set_title('Volume vs. Cost')
plt.xlabel('Volume (liter)')
plt.ylabel('Cost')
plt.xlim([0.25,6.200])
plt.ylim([0.5,70])
plt.show()

# %% [markdown]
# # Scatterplot: Cost vs. Retail Price

# %%
f,ax=plt.subplots(figsize=(17,10))
plt.scatter(df_item['Bottle_Cost'], df_item['Bottle_Retail_Price'], alpha = 0.35)
ax.set_title('Cost vs. Retail Price--No Limits')
ax.set_ylim(ymin = 0)
ax.set_xlim(xmin = 0)
plt.xlabel('Cost')
plt.ylabel('Retail Price')
plt.show()

# %%
f,ax=plt.subplots(figsize=(17,10))
plt.scatter(df_item['Bottle_Cost'], df_item['Bottle_Retail_Price'], alpha = 0.25)
ax.set_title('Cost vs. Retail Price')
plt.xlabel('Cost')
plt.ylabel('Retail Price')
ax.set_ylim(ymin = 0)
ax.set_xlim(xmin = 0)
plt.xlim([1,100])
plt.ylim([1,150])
plt.show()

# %% [markdown]
# # Scatterplot: Cost vs. Pack Number

# %%
f,ax=plt.subplots(figsize=(17,10))
plt.scatter(df_item['Bottle_Cost'], df_item['Pack'], edgecolor = 'black', alpha = 0.25)
ax.set_title('Cost vs. Pack Number--No Limits')
plt.xlabel('Cost')
plt.ylabel('Pack Number')
ax.set_ylim(ymin = 0)
ax.set_xlim(xmin = 0)
plt.show()

# %%
f,ax=plt.subplots(figsize=(17,10))
plt.scatter(df_item['Bottle_Cost'], df_item['Pack'], edgecolor = 'black', alpha = 0.25)
ax.set_title('Cost vs. Pack Number')
plt.xlabel('Cost')
plt.ylabel('Pack Number')
ax.set_ylim(ymin = 0)
ax.set_xlim(xmin = 0)
plt.xlim([0,100])
plt.ylim([0,100])
plt.show()

# %%
f,ax=plt.subplots(figsize=(17,10))
plt.scatter(df_item['Bottle_Volume_ml']/1000, df_item['Pack'], edgecolor = 'black', alpha = 0.5)
plt.xlabel('Volume (liter)')
plt.ylabel('Pack Number')
ax.set_title('Volume vs. Pack Number--No Limits')
plt.show()

# %%
f,ax=plt.subplots(figsize=(17,10))
plt.scatter(df_item['Bottle_Volume_ml']/1000, df_item['Pack'], edgecolor = 'black', alpha = 0.5)
plt.xlabel('Volume (liter)')
plt.ylabel('Pack Number')
ax.set_title('Volume vs. Pack Number')
plt.xlim([0,8])
plt.ylim([0,100])
plt.show()

# %%
f,ax=plt.subplots(figsize=(17,10))
plt.scatter(df_item['Bottle_Volume_ml']/1000, df_item['Bottle_Retail_Price'], alpha = 0.35)
ax.set_title('Volume vs. Retail Price--No Limits')
plt.xlabel('Volume (liter)')
plt.ylabel('Retail Price')
plt.show()

# %%
f,ax=plt.subplots(figsize=(17,10))
plt.scatter(df_item['Bottle_Volume_ml']/1000, df_item['Bottle_Retail_Price'], alpha = 0.35)
ax.set_title('Volume vs. Retail Price--No Limits')
plt.xlabel('Volume (liter)')
plt.ylabel('Retail Price')
plt.xlim([0,6.5])
plt.ylim([0,100])
plt.show()

# %%
df_item['Category'].unique()
# Out:
# array(['Grapefruit Soda', 'Fruit Punch', nan, 'Cream Soda', 'Cherry Soda',
#        'Blueberry Soda', 'Root Beer', 'Cola', 'Ginger Ale',
#        'Energy Drink', 'Orange Soda', 'Lime Soda', 'Raspberry Soda'],
#       dtype=object)
