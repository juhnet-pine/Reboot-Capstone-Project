# %% [markdown]
# # Merging the Database Part 1
# Once the data have been loaded into three separate tables, which I will here call invoices, items, and reviews, you should merge them into each other. Your two master records are the invoices, which should never change in number, and the reviews, which are similarly fixed. The item data can be combined with those.
#
# If using Pandas, you should use a left join on invoices with items.
#
# This should yield a merged database, invoices_all, which contains the invoices as records and includes information about each item sold.

# %%
import pandas as pd

df_item = pd.read_csv('data_code/item.csv')
df_invoice = pd.read_csv('data_code/invoice.csv')
df_review = pd.read_csv('data_code/reviews_df.csv')

# %%
df_review.head()
# Out:
#    Review_id  Customer_id    Invoice_id  Rating
# 0      10631         2584  S09611900003     1.0
# 1      41318         9650  S16490800006     4.0
# 2        422         4080  S30092800002     2.0
# 3      46477         1468  S22572400028     1.0
# 4      49744         5053  S26103700065     3.0

# %%
df_review.sample(n=10)
# Out:
#        Review_id  Customer_id       Invoice_id  Rating
# 41711      20459         3754     S30724800008     2.0
# 5303       28794         1895     S28494900022     1.0
# 38117      30701         2433     S32990200061     2.0
# 4134       22535         1090     S27675600015     4.0
# 16111      41608         1380     S20509900045     4.0
# 24015      22586         7454  INV-05915600035     3.0
# 1780       11300         8145     S16219100010     3.0
# 40315      46494         5763  INV-04595400105     2.0
# 10308       5629         1986     S24482700015     3.0
# 17414      18344         1903     S12337400119     4.0

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Review_id    50000 non-null  int64
#  1   Customer_id  50000 non-null  int64
#  2   Invoice_id   50000 non-null  object
#  3   Rating       50000 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.5+ MB

# %%
df_item.head()
# Out:
#    Item_id           Item_Description         Category  Pack  \
# 0      101    Kanna's Grapefruit Soda  Grapefruit Soda     6
# 1      102     Alphonse's Fruit Punch      Fruit Punch     6
# 2      103   Yummy Surstromming Juice              NaN     1
# 3      107  Tamaki's Watermelon Cream       Cream Soda     6
# 4      108    Kaori's Grapefruit Soda  Grapefruit Soda     6
#
#    Bottle_Volume_ml  Bottle_Cost  Bottle_Retail_Price
# 0             750.0         4.32                 6.48
# 1             800.0         3.33                 5.00
# 2             750.0        10.30                20.10
# 3             750.0         4.44                 6.66
# 4             750.0         3.12                 4.68

# %%
df_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4166 entries, 0 to 4165
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Item_id              4166 non-null   int64
#  1   Item_Description     4166 non-null   object
#  2   Category             4162 non-null   object
#  3   Pack                 4166 non-null   int64
#  4   Bottle_Volume_ml     4166 non-null   float64
#  5   Bottle_Cost          4166 non-null   float64
#  6   Bottle_Retail_Price  4163 non-null   float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 228.0+ KB

# %%
df_invoice.head()
# Out:
#         Invoice_id        Date  Item_id  Vendor_id        Vendor_Name  \
# 0  INV-00013400001  2016-08-29    35918        297      Katou Company
# 1  INV-00013400002  2016-08-29    23828        297      Katou Company
# 2  INV-00013400003  2016-08-29    36908        300  Katsuragi Company
# 3  INV-00013400004  2016-08-29    34359         35        Archer Inc.
# 4  INV-00013400005  2016-08-29    36903        300  Katsuragi Company
#
#    Store_id                  Store_Name            Address  City_Name  \
# 0      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
# 1      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
# 2      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
# 3      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
# 4      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
#
#    Zip_Code  County_id County_Name  Bottles_Sold
# 0     52802         82       Scott             1
# 1     52802         82       Scott             1
# 2     52802         82       Scott             1
# 3     52802         82       Scott             8
# 4     52802         82       Scott             1

# %%
df_invoice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 930508 entries, 0 to 930507
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Invoice_id    930508 non-null  object
#  1   Date          930508 non-null  object
#  2   Item_id       930508 non-null  int64
#  3   Vendor_id     930508 non-null  int64
#  4   Vendor_Name   930508 non-null  object
#  5   Store_id      930508 non-null  int64
#  6   Store_Name    930508 non-null  object
#  7   Address       930508 non-null  object
#  8   City_Name     930508 non-null  object
#  9   Zip_Code      930508 non-null  int64
#  10  County_id     930508 non-null  int64
#  11  County_Name   930508 non-null  object
#  12  Bottles_Sold  930508 non-null  int64
# dtypes: int64(6), object(7)
# memory usage: 92.3+ MB

# %%
df_invoices_all= pd.merge(df_invoice, df_item, on = 'Item_id', how ='left')
df_invoices_all.head()
# Out:
#         Invoice_id        Date  Item_id  Vendor_id        Vendor_Name  \
# 0  INV-00013400001  2016-08-29    35918        297      Katou Company
# 1  INV-00013400002  2016-08-29    23828        297      Katou Company
# 2  INV-00013400003  2016-08-29    36908        300  Katsuragi Company
# 3  INV-00013400004  2016-08-29    34359         35        Archer Inc.
# 4  INV-00013400005  2016-08-29    36903        300  Katsuragi Company
#
#    Store_id                  Store_Name            Address  City_Name  \
# 0      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
# 1      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
# 2      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
# 3      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
# 4      3882  Kwik Shop #579 / Davenport  2805 TELEGRAPH RD  DAVENPORT
#
#    Zip_Code  County_id County_Name  Bottles_Sold  \
# 0     52802         82       Scott             1
# 1     52802         82       Scott             1
# 2     52802         82       Scott             1
# 3     52802         82       Scott             8
# 4     52802         82       Scott             1
#
#                       Item_Description     Category  Pack  Bottle_Volume_ml  \
# 0  Haruko's Family Secret Black Cherry  Cherry Soda     6            1750.0
# 1                  Archer's Cream Soda   Cream Soda     6            1750.0
# 2                   Joutarou's Red Pop  Cherry Soda     6            1750.0
# 3                    Roy's Wild Cherry  Cherry Soda    12             200.0
# 4                 Hisoka's Wild Cherry  Cherry Soda    48             200.0
#
#    Bottle_Cost  Bottle_Retail_Price
# 0         2.51                 3.76
# 1         2.54                 3.81
# 2         2.55                 3.83
# 3         2.18                 3.27
# 4         1.66                 2.49

# %%
df_invoices_all.tail()
# Out:
#           Invoice_id        Date  Item_id  Vendor_id          Vendor_Name  \
# 930503  S34122500013  2016-08-25    68031        260      Inuyasha Brands
# 930504  S34122500014  2016-08-25    75212        322        Koizumi Group
# 930505  S34122500015  2016-08-25    75224        322        Koizumi Group
# 930506  S34122500016  2016-08-25    36901        300    Katsuragi Company
# 930507  S34122500017  2016-08-25    86692         85  Ayuzawa Corporation
#
#         Store_id                 Store_Name                 Address  \
# 930503      4694  Rina Mart LLC / Davenport  3815, WEST KIMBERLY RD
# 930504      4694  Rina Mart LLC / Davenport  3815, WEST KIMBERLY RD
# 930505      4694  Rina Mart LLC / Davenport  3815, WEST KIMBERLY RD
# 930506      4694  Rina Mart LLC / Davenport  3815, WEST KIMBERLY RD
# 930507      4694  Rina Mart LLC / Davenport  3815, WEST KIMBERLY RD
#
#         City_Name  Zip_Code  County_id County_Name  Bottles_Sold  \
# 930503  DAVENPORT     52806         82       Scott             1
# 930504  DAVENPORT     52806         82       Scott             6
# 930505  DAVENPORT     52806         82       Scott             6
# 930506  DAVENPORT     52806         82       Scott             6
# 930507  DAVENPORT     52806         82       Scott            12
#
#                  Item_Description     Category  Pack  Bottle_Volume_ml  \
# 930503  Deishuu's Craft Root Beer    Root Beer     4            1000.0
# 930504    Conan's Plum and Ginger   Ginger Ale     6             500.0
# 930505    Daiki's Plum and Ginger   Ginger Ale     6             500.0
# 930506           Hisoka's Red Pop  Cherry Soda     6             500.0
# 930507  Kosaki's Watermelon Cream   Cream Soda    12             750.0
#
#         Bottle_Cost  Bottle_Retail_Price
# 930503         5.06                 7.59
# 930504         2.20                 3.30
# 930505         2.18                 3.27
# 930506         2.16                 3.24
# 930507         3.62                 5.43

# %%
df_invoices_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 930508 entries, 0 to 930507
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Invoice_id           930508 non-null  object
#  1   Date                 930508 non-null  object
#  2   Item_id              930508 non-null  int64
#  3   Vendor_id            930508 non-null  int64
#  4   Vendor_Name          930508 non-null  object
#  5   Store_id             930508 non-null  int64
#  6   Store_Name           930508 non-null  object
#  7   Address              930508 non-null  object
#  8   City_Name            930508 non-null  object
#  9   Zip_Code             930508 non-null  int64
#  10  County_id            930508 non-null  int64
#  11  County_Name          930508 non-null  object
#  12  Bottles_Sold         930508 non-null  int64
#  13  Item_Description     930508 non-null  object
#  14  Category             930483 non-null  object
#  15  Pack                 930508 non-null  int64
#  16  Bottle_Volume_ml     930508 non-null  float64
#  17  Bottle_Cost          930508 non-null  float64
#  18  Bottle_Retail_Price  930190 non-null  float64
# dtypes: float64(3), int64(7), object(9)
# memory usage: 142.0+ MB

# %%
df_invoices_all.sample(n=15)
# Out:
#              Invoice_id        Date  Item_id  Vendor_id          Vendor_Name  \
# 506309     S16084700042  2013-12-04    36908        300    Katsuragi Company
# 863077     S31504800027  2016-03-30    36901        300    Katsuragi Company
# 334407     S08282800001  2012-10-15     1012        420       Michaelis Inc.
# 51400   INV-02306800009  2016-12-21     4616        260      Inuyasha Brands
# 610416     S20731100010  2014-08-20    11786        115        Deviluke Inc.
# 538440     S17496500092  2014-02-19    42166        260      Inuyasha Brands
# 377432     S10123200015  2013-01-21    65204        300    Katsuragi Company
# 8472    INV-00333000044  2016-09-15    20246         65       Ayanami Brands
# 143303  INV-06178800110  2017-07-19    19477         65       Ayanami Brands
# 804879     S29161100152  2015-11-18    41857        380           Le Company
# 160531  INV-06860500030  2017-08-24    37991        260      Inuyasha Brands
# 694104     S24384500034  2015-03-05    27668        306         Kirigaya Co.
# 25411   INV-01199800018  2016-10-26    19063         65       Ayanami Brands
# 145837  INV-06251200056  2017-07-24    36307        434           Minami LLC
# 711678     S25139400030  2015-04-20    86884         85  Ayuzawa Corporation
#
#         Store_id                         Store_Name               Address  \
# 506309      2637              Hy-Vee #5 / Davenport         2351 W LOCUST
# 863077      3715          Kimberly Mart / Davenport    1714 E KIMBERLY RD
# 334407      2621  Hy-Vee Food Store #3 / Sioux City        3301 GORDON DR
# 51400       2625        Hy-Vee Convenience Store #2    3301 W KIMBERLY RD
# 610416      4200   Fareway Stores #019 / Sioux City  4016 INDIAN HILLS DR
# 538440      2614       Hy-Vee #3 Food and Drugstore    1823 E KIMBERLY RD
# 377432      4452           Select Mart    Gordon Dr        2825 GORDON DR
# 8472        2635              Hy-Vee #4 / Davenport        4064 E 53RD ST
# 143303      2625        Hy-Vee Convenience Store #2    3301 W KIMBERLY RD
# 804879      2625        Hy-Vee Convenience Store #2    3301 W KIMBERLY RD
# 160531      5029                  The Durg Stop LLC        211, W 53RD ST
# 694104      2567       Hy-Vee Drugstore / Davenport    2200 WEST KIMBERLY
# 25411       4452           Select Mart    Gordon Dr        2825 GORDON DR
# 145837      3917     Smokin' Joe's #2 Food and Durg      1606 W LOCUST ST
# 711678      4644         Kwik Shop #588 / Davenport     1136, E LOCUST ST
#
#          City_Name  Zip_Code  County_id County_Name  Bottles_Sold  \
# 506309   DAVENPORT     52804         82       Scott            12
# 863077   DAVENPORT     52807         82       Scott             3
# 334407  SIOUX CITY     51105         97    Woodbury             2
# 51400    DAVENPORT     52804         82       Scott             1
# 610416  SIOUX CITY     51108         97    Woodbury            12
# 538440   DAVENPORT     52807         82       Scott             3
# 377432  SIOUX CITY     51105         97    Woodbury             4
# 8472     DAVENPORT     52807         82       Scott             1
# 143303   DAVENPORT     52804         82       Scott             1
# 804879   DAVENPORT     52804         82       Scott             2
# 160531   DAVENPORT     52806         82       Scott             1
# 694104   DAVENPORT     52806         82       Scott            36
# 25411   SIOUX CITY     51105         97    Woodbury             8
# 145837   DAVENPORT     52804         82       Scott             1
# 711678   DAVENPORT     52803         82       Scott            10
#
#                    Item_Description      Category  Pack  Bottle_Volume_ml  \
# 506309           Joutarou's Red Pop   Cherry Soda     6            1750.0
# 863077             Hisoka's Red Pop   Cherry Soda     6             500.0
# 334407      Gilgamesh's Fruit Punch   Fruit Punch     6             750.0
# 51400            Osamu's Cream Soda    Cream Soda     6             750.0
# 610416  Meliodas's Watermelon Cream    Cream Soda    12             750.0
# 538440                 Roy's Energy  Energy Drink    12             750.0
# 377432    Chopper's Craft Root Beer     Root Beer     6             500.0
# 8472            Hisoka's Cream Soda    Cream Soda    12             750.0
# 143303    Himeko's Watermelon Cream    Cream Soda    12            1000.0
# 804879              Meiko's Red Pop   Cherry Soda     6             500.0
# 160531               Ippo's Red Pop   Cherry Soda    12             500.0
# 694104   Daiki's Vanilla Cream Soda    Cream Soda    12             375.0
# 25411           Haruko's Cream Soda    Cream Soda    48             200.0
# 145837        Himeko's Black Cherry   Cherry Soda    12            1000.0
# 711678    Shouyou's Craft Root Beer     Root Beer    24             375.0
#
#         Bottle_Cost  Bottle_Retail_Price
# 506309         2.55                 3.83
# 863077         2.16                 3.24
# 334407         4.31                 6.46
# 51400          7.07                10.61
# 610416         2.24                 3.36
# 538440         2.91                 4.36
# 377432         2.43                 3.65
# 8472           2.13                 3.20
# 143303         4.61                 6.92
# 804879         2.19                 3.29
# 160531         2.55                 3.82
# 694104         2.78                 4.17
# 25411          1.90                 2.85
# 145837         2.06                 3.09
# 711678         2.14                 3.21

# %%
df_invoices_all.to_csv('data_code/invoices_all.csv',index = False)

# %%
invoices_all = pd.read_csv('data_code/invoices_all.csv')

# %%
invoices_all.tail()
# Out:
#           Invoice_id        Date  Item_id  Vendor_id          Vendor_Name  \
# 930503  S34122500013  2016-08-25    68031        260      Inuyasha Brands
# 930504  S34122500014  2016-08-25    75212        322        Koizumi Group
# 930505  S34122500015  2016-08-25    75224        322        Koizumi Group
# 930506  S34122500016  2016-08-25    36901        300    Katsuragi Company
# 930507  S34122500017  2016-08-25    86692         85  Ayuzawa Corporation
#
#         Store_id                 Store_Name                 Address  \
# 930503      4694  Rina Mart LLC / Davenport  3815, WEST KIMBERLY RD
# 930504      4694  Rina Mart LLC / Davenport  3815, WEST KIMBERLY RD
# 930505      4694  Rina Mart LLC / Davenport  3815, WEST KIMBERLY RD
# 930506      4694  Rina Mart LLC / Davenport  3815, WEST KIMBERLY RD
# 930507      4694  Rina Mart LLC / Davenport  3815, WEST KIMBERLY RD
#
#         City_Name  Zip_Code  County_id County_Name  Bottles_Sold  \
# 930503  DAVENPORT     52806         82       Scott             1
# 930504  DAVENPORT     52806         82       Scott             6
# 930505  DAVENPORT     52806         82       Scott             6
# 930506  DAVENPORT     52806         82       Scott             6
# 930507  DAVENPORT     52806         82       Scott            12
#
#                  Item_Description     Category  Pack  Bottle_Volume_ml  \
# 930503  Deishuu's Craft Root Beer    Root Beer     4            1000.0
# 930504    Conan's Plum and Ginger   Ginger Ale     6             500.0
# 930505    Daiki's Plum and Ginger   Ginger Ale     6             500.0
# 930506           Hisoka's Red Pop  Cherry Soda     6             500.0
# 930507  Kosaki's Watermelon Cream   Cream Soda    12             750.0
#
#         Bottle_Cost  Bottle_Retail_Price
# 930503         5.06                 7.59
# 930504         2.20                 3.30
# 930505         2.18                 3.27
# 930506         2.16                 3.24
# 930507         3.62                 5.43

# %% [markdown]
# # Merging the Database Part 2
# Do the same for the reviews with the item data in reviews_all, except that you should left join on reviews with invoices, as not all invoice purchases generated reviews. You should verify that you can obtain item IDs and rating numbers from the same database, as that will be necessary for the recommendation engine step below.

# %%
df_reviews_all= pd.merge(invoices_all, df_review, on = 'Invoice_id', how ='left')

# %%
df_reviews_all.sample(n=5)
# Out:
#              Invoice_id        Date  Item_id  Vendor_id      Vendor_Name  \
# 99875   INV-04329900060  2017-04-12    77632        260  Inuyasha Brands
# 802792     S29041000044  2015-11-12    43128         35      Archer Inc.
# 467456     S14181400070  2013-08-28    67556         65   Ayanami Brands
# 39923   INV-01775300022  2016-11-23    37418        260  Inuyasha Brands
# 427143     S12301000024  2013-05-20    45886        240        Howl INC.
#
#         Store_id                         Store_Name             Address  \
# 99875       2594     Hy-Vee Food Store / Sioux City  4500 SERGEANT ROAD
# 802792      2635              Hy-Vee #4 / Davenport      4064 E 53RD ST
# 467456      2621  Hy-Vee Food Store #3 / Sioux City      3301 GORDON DR
# 39923       3757         Wal-Mart 3590 / Sioux City     3101 FLOYD BLVD
# 427143      4201   Fareway Stores #022 / Sioux City   4040 WAR EAGLE DR
#
#          City_Name  Zip_Code  ...  Bottles_Sold  \
# 99875   SIOUX CITY     51106  ...             2
# 802792   DAVENPORT     52807  ...             6
# 467456  SIOUX CITY     51105  ...            12
# 39923   SIOUX CITY     51108  ...             1
# 427143  SIOUX CITY     51109  ...             6
#
#                            Item_Description      Category Pack  \
# 99875    Motoko's Gourmet Black Cherry Soda   Cherry Soda   12
# 802792             Alucard's Energy Booster  Energy Drink    6
# 467456              Asuna's Craft Root Beer     Root Beer   12
# 39923   Ichigo's Family Secret Black Cherry   Cherry Soda    6
# 427143                Maki's Energy Booster  Energy Drink   12
#
#        Bottle_Volume_ml  Bottle_Cost  Bottle_Retail_Price  Review_id  \
# 99875             750.0         2.66                 3.99        NaN
# 802792           1750.0         3.57                 5.35        NaN
# 467456            750.0         2.39                 3.58        NaN
# 39923            1750.0         2.70                 4.05        NaN
# 427143            750.0         2.64                 4.12    15786.0
#
#         Customer_id  Rating
# 99875           NaN     NaN
# 802792          NaN     NaN
# 467456          NaN     NaN
# 39923           NaN     NaN
# 427143       5863.0     3.0
#
# [5 rows x 22 columns]

# %%
df_reviews_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 931812 entries, 0 to 931811
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Invoice_id           931812 non-null  object
#  1   Date                 931812 non-null  object
#  2   Item_id              931812 non-null  int64
#  3   Vendor_id            931812 non-null  int64
#  4   Vendor_Name          931812 non-null  object
#  5   Store_id             931812 non-null  int64
#  6   Store_Name           931812 non-null  object
#  7   Address              931812 non-null  object
#  8   City_Name            931812 non-null  object
#  9   Zip_Code             931812 non-null  int64
#  10  County_id            931812 non-null  int64
#  11  County_Name          931812 non-null  object
#  12  Bottles_Sold         931812 non-null  int64
#  13  Item_Description     931812 non-null  object
#  14  Category             931787 non-null  object
#  15  Pack                 931812 non-null  int64
#  16  Bottle_Volume_ml     931812 non-null  float64
#  17  Bottle_Cost          931812 non-null  float64
#  18  Bottle_Retail_Price  931494 non-null  float64
#  19  Review_id            50000 non-null   float64
#  20  Customer_id          50000 non-null   float64
#  21  Rating               50000 non-null   float64
# dtypes: float64(6), int64(7), object(9)
# memory usage: 163.5+ MB

# %%
df_reviews_all['Rating'].sample(n=20)
# Out:
# 495019    NaN
# 784343    NaN
# 559464    NaN
# 155660    NaN
# 419989    NaN
# 701658    NaN
# 792978    1.0
# 875939    NaN
# 667922    NaN
# 751212    NaN
# 28916     NaN
# 385184    NaN
# 581688    NaN
# 330437    NaN
# 334587    NaN
# 534790    NaN
# 452527    NaN
# 772027    NaN
# 114084    NaN
# 686316    NaN
# Name: Rating, dtype: float64

# %%
df_reviews_all['Item_id'].sample(n=20)
# Out:
# 359597    37993
# 54098     53206
# 724887    43333
# 291239    36886
# 463583     8827
# 342300     5347
# 730356    78616
# 859397    11296
# 753151    11788
# 521392    17956
# 693280    86669
# 368445    42716
# 82103     28233
# 826021    88294
# 70584     40052
# 446390    28233
# 678228    25608
# 396974    47786
# 360230    74772
# 126885    29712
# Name: Item_id, dtype: int64

# %%
df_reviews_all.to_csv('data_code/data_all.csv',index = False)

# %%
df_data_all = pd.read_csv('data_code/data_all.csv')
df_data_all.sample(n=10)
# Out:
#              Invoice_id        Date  Item_id  Vendor_id      Vendor_Name  \
# 365347     S09611700037  2012-12-20    19068         65   Ayanami Brands
# 136754  INV-05912200167  2017-07-05    52595        205       Harima Co.
# 332663     S08185500008  2012-10-09    24457         65   Ayanami Brands
# 883902     S32263000158  2016-05-11    45277        434       Minami LLC
# 432077     S12523900025  2013-05-31    87937        434       Minami LLC
# 359845     S09426000008  2012-12-11    68036        260  Inuyasha Brands
# 687425     S24105500123  2015-02-18    41693        380       Le Company
# 61905   INV-02663200121  2017-01-11    88294        410  Megumin Company
# 484957     S15028700045  2013-10-09    12407         55   Arlert Company
# 316283     S07417200156  2012-08-29    82613         65   Ayanami Brands
#
#         Store_id                         Store_Name             Address  \
# 365347      3540    Super Target T-0533 / Davenport     5225 ELMORE AVE
# 136754      2621  Hy-Vee Food Store #3 / Sioux City      3301 GORDON DR
# 332663      3354        Sam's Club 8238 / Davenport    3845 ELMORE AVE.
# 883902      2625        Hy-Vee Convenience Store #2  3301 W KIMBERLY RD
# 432077      2625        Hy-Vee Convenience Store #2  3301 W KIMBERLY RD
# 359845      2614       Hy-Vee #3 Food and Drugstore  1823 E KIMBERLY RD
# 687425      2621  Hy-Vee Food Store #3 / Sioux City      3301 GORDON DR
# 61905       2614       Hy-Vee #3 Food and Drugstore  1823 E KIMBERLY RD
# 484957      3986                 Siouxland Beverage           1203 5 ST
# 316283      2594     Hy-Vee Food Store / Sioux City  4500 SERGEANT ROAD
#
#          City_Name  Zip_Code  ...  Bottles_Sold  \
# 365347   DAVENPORT     52807  ...             6
# 136754  SIOUX CITY     51105  ...             3
# 332663   DAVENPORT     52807  ...            24
# 883902   DAVENPORT     52804  ...            24
# 432077   DAVENPORT     52804  ...            24
# 359845   DAVENPORT     52807  ...            36
# 687425  SIOUX CITY     51105  ...            12
# 61905    DAVENPORT     52807  ...             1
# 484957  SIOUX CITY     51101  ...             2
# 316283  SIOUX CITY     51106  ...             1
#
#                            Item_Description      Category Pack  \
# 365347            Haruko's Watermelon Cream    Cream Soda    6
# 136754                 Haruhi's Orange Soda   Orange Soda   12
# 332663             Armin's Watermelon Cream    Cream Soda   12
# 883902               Dante's Energy Booster  Energy Drink   12
# 432077                         Ginko's Kola          Cola   12
# 359845                  Deishuu's Root Beer     Root Beer   12
# 687425  Mayuri's Family Secret Black Cherry   Cherry Soda   12
# 61905                       Griffith's Cola          Cola   12
# 484957          Mikasa's Vanilla Cream Soda    Cream Soda   12
# 316283                     Kyon's Root Beer     Root Beer   24
#
#        Bottle_Volume_ml  Bottle_Cost  Bottle_Retail_Price  Review_id  \
# 365347           1750.0         4.09                 6.13        NaN
# 136754            750.0         2.28                 3.42        NaN
# 332663           1000.0         2.50                 3.75        NaN
# 883902           1000.0         2.11                 3.16        NaN
# 432077           1000.0         2.44                 3.66        NaN
# 359845            750.0         3.37                 5.06    49194.0
# 687425            750.0         2.42                 3.63        NaN
# 61905             375.0         3.47                 5.20        NaN
# 484957           1000.0         2.25                 3.37        NaN
# 316283            375.0         1.93                 2.90        NaN
#
#         Customer_id  Rating
# 365347          NaN     NaN
# 136754          NaN     NaN
# 332663          NaN     NaN
# 883902          NaN     NaN
# 432077          NaN     NaN
# 359845       3585.0     5.0
# 687425          NaN     NaN
# 61905           NaN     NaN
# 484957          NaN     NaN
# 316283          NaN     NaN
#
# [10 rows x 22 columns]
